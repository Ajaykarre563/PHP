# %% [markdown]
# # **simple website**

# %% [markdown]
# # **index.php**

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Home Page</title>
#     <link rel="stylesheet" href="style.css">
# </head>
# <body>
#     <div class="container">
#     <?php
#         include_once("header.php");
#     ?>
#     <?php
#         include_once("footer.php");
#     ?>
#     <?php
#         include_once("about.php");
#     ?>
#     <?php
#         include_once("contact.php");
#     ?>
#
#
#     <h1>Welcome to Our Website</h1>
#     <p>We are glad to have you here! Explore our website to learn more about us and get in touch.</p>
#
#
# </body>
# </html>
#
# ```

# %% [markdown]
# # **about.php**

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>About Page</title>
#     <link rel="stylesheet" href="style.css">
# </head>
# <body>
#     <div class="container">
#     <?php include_once("header.php"); ?>
#
#     <h1>About Us</h1>
#     <p>Welcome to the About page of our website!</p>
#
#     <?php include_once("footer.php"); ?>
# </body>
# </html>
#
# ```

# %% [markdown]
# # **contact.php**

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Contact Page</title>
#     <link rel="stylesheet" href="style.css">
# </head>
# <body>
#     <div class="container">
#     <?php include_once("header.php"); ?>
#
#     <h1>Contact Us</h1>
#     <form action="contact.php" method="POST">
#         <label>Name:</label>
#         <input type="text" name="name" required>
#
#         <label>Email:</label>
#         <input type="email" name="email" required>
#
#         <label>Message:</label>
#         <textarea name="message" required></textarea>
#
#         <button type="submit">Send</button>
#     </form>
#
#     <?php include_once("footer.php"); ?>
# </body>
# </html>
#
# <?php
# if ($_SERVER["REQUEST_METHOD"] == "POST") {
#     $name = $_POST['name'];
#     $email = $_POST['email'];
#     $message = $_POST['message'];
#
#     file_put_contents("messages.txt", "Name: $name\nEmail: $email\nMessage: $message\n\n", FILE_APPEND);
#     echo "<p>Message sent successfully!</p>";
# }
# ?>
#
# ```

# %% [markdown]
# # **style.css**

# %% [markdown]
# ```
# .container {
#     margin-left: 10%;
#     margin-right: 10%;
# }
#
# .heading {
#     color: orange;
# }
#
# .header {
#     display: flex;
#     justify-content: space-between;
#     align-items: center;
#     width: 100%;
#     padding: 10px 0;
# }
#
# .header ul {
#     list-style: none;
#     display: flex;
#     padding: 0;
#     margin: 0;
# }
#
# .header ul li {
#     width: 60px;
#     text-align: center;
# }
#
# .header ul li a {
#     text-decoration: none;
#     color: black;
#     font-weight: bold;
#     transition: color 0.3s ease-in-out;
# }
#
# .header ul li a:hover {
#     color: orange;
# }
#
# ```

# %% [markdown]
# # **header.php**

# %% [markdown]
# ```
# <div class="header">
#     <h3>LOGO</h3>
#     <nav>
#         <ul>
#             <li><a href="index.php">Home</a></li>
#             <li><a href="about.php">About</a></li>
#             <li><a href="contact.php">Contact</a></li>
#         </ul>
#     </nav>
# </div>
#
# ```

# %% [markdown]
# # **footer.php**

# %% [markdown]
# ```
# <footer class="footer">
#     <nav>
#         <ul>
#             <li><a href="index.php">Home</a></li>
#             <li><a href="about.php">About</a></li>
#             <li><a href="contact.php">Contact</a></li>
#         </ul>
#     </nav>
# </footer>
#
# ```

# %% [markdown]
# ![Screenshot 2025-04-04 180012.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-04 180054.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-04 180128.png](data:image/png;base64,...)
