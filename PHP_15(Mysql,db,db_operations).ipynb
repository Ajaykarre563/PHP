# %% [markdown]
# # **✅ What is MySQL?**
#
# **Database Management System (DBMS):**
#
# MySQL is a Relational DBMS (RDBMS) that allows you to store, manage, and retrieve data efficiently.
#
# **Structured Collection of Data:**
#
# A database is like a digital filing cabinet where data is stored in tables, organized by rows and columns.
#
# **Structured Format Management:**
#
# You can use SQL queries to insert, update, delete, and fetch data in a very organized manner.
#
# **Developed by Oracle:**
#
# Although MySQL started as an open-source project, it is now maintained and developed by Oracle Corporation.

# %% [markdown]
# ![Screenshot 2025-04-05 183259.png](data:image/png;base64,...)

# %% [markdown]
# # **✅ What is a Database?**
#
# # **Definition:**
#
# A database is a collection of structured information or data, stored electronically and accessible in a logical, organized way.
#
# **Real-Life Examples in Web Apps:**
#
# 🔹 Users of a website: Login credentials, profiles, preferences
#
# 🔹 Products of e-commerce websites: Name, price, stock, description
#
# 🔹 Almost every big website uses a database — think Amazon, YouTube, Facebook, etc.

# %% [markdown]
# # **✅ Database and Language – Simple Explanation**
#
# A database is not a programming language.
# It’s used to store data like names, emails, products, etc.
#
# PHP (or Java) is a programming language.
# It's used to write code and connect with the database.
#
# We use programming languages like PHP to add, update, or get data from the database.
#
# **Some popular database tools are:**
#
# MySQL
#
# Oracle
#
# SQL Server
#
# # **Why not just use variables or arrays in PHP?**
#
# Because they are temporary — the data disappears when the page reloads.
# But a database stores data permanently.

# %% [markdown]
# # **DataBase Operations**

# %% [markdown]
# # **1. All operations with UI and SQL**
#
# In PHP, UI can be built using HTML/CSS, and SQL is executed through PHP scripts.

# %% [markdown]
# # **2. What is SQL?**
#
# SQL (Structured Query Language) is used to communicate with a database. It allows you to create, read, update, and delete (CRUD) data.

# %% [markdown]
# # **3. Create Database**

# %% [markdown]
# ```
# <?php
# $servername = "localhost";
# $username = "root";
# $password = "";
#
# // Create connection
# $conn = new mysqli($servername, $username, $password);
#
# // Check connection
# if ($conn->connect_error) {
#     die("Connection failed: " . $conn->connect_error);
# }
#
# // Create database
# $sql = "CREATE DATABASE myDB";
# if ($conn->query($sql) === TRUE) {
#     echo "Database created successfully";
# } else {
#     echo "Error creating database: " . $conn->error;
# }
#
# $conn->close();
# ?>
#
# ```

# %% [markdown]
# # **4. Database List**

# %% [markdown]
# ```
# <?php
# $conn = new mysqli("localhost", "root", "");
#
# $sql = "SHOW DATABASES";
# $result = $conn->query($sql);
#
# while ($row = $result->fetch_assoc()) {
#     echo $row['Database'] . "<br>";
# }
#
# $conn->close();
# ?>
#
# ```

# %% [markdown]
# # **5. Delete Database**

# %% [markdown]
# ```
# <?php
# $conn = new mysqli("localhost", "root", "");
#
# $sql = "DROP DATABASE myDB";
# if ($conn->query($sql) === TRUE) {
#     echo "Database deleted successfully";
# } else {
#     echo "Error deleting database: " . $conn->error;
# }
#
# $conn->close();
# ?>
#
# ```
